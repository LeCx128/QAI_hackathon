# %%
# !pip install cvxpy
# !pip install pymoo==0.5.0
# Out:
# Collecting cvxpy
#   Using cached cvxpy-1.7.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting osqp>=1.0.0 (from cvxpy)
#   Using cached osqp-1.0.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy)
#   Using cached clarabel-0.11.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy)
#   Using cached scs-3.2.9-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.12/site-packages (from cvxpy) (2.3.3)
# Requirement already satisfied: scipy>=1.13.0 in /opt/conda/lib/python3.12/site-packages (from cvxpy) (1.16.2)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.12/site-packages (from clarabel>=0.5.0->cvxpy) (1.17.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from osqp>=1.0.0->cvxpy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from osqp>=1.0.0->cvxpy) (80.9.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from osqp>=1.0.0->cvxpy) (1.5.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi->clarabel>=0.5.0->cvxpy) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->osqp>=1.0.0->cvxpy) (3.0.2)
# Using cached cvxpy-1.7.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
# Using cached clarabel-0.11.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached osqp-1.0.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (357 kB)
# Using cached scs-3.2.9-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (12.1 MB)
# Installing collected packages: scs, osqp, clarabel, cvxpy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [cvxpy]32m3/4 [cvxpy]el]
# Successfully installed clarabel-0.11.1 cvxpy-1.7.3 osqp-1.0.5 scs-3.2.9
# Collecting pymoo==0.5.0
#   Using cached pymoo-0.5.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.12/site-packages (from pymoo==0.5.0) (2.3.3)
# Requirement already satisfied: scipy>=1.1 in /opt/conda/lib/python3.12/site-packages (from pymoo==0.5.0) (1.16.2)
# Requirement already satisfied: matplotlib>=3 in /opt/conda/lib/python3.12/site-packages (from pymoo==0.5.0) (3.10.7)
# Requirement already satisfied: autograd>=1.3 in /opt/conda/lib/python3.12/site-packages (from pymoo==0.5.0) (1.8.0)
# Collecting cma==2.7 (from pymoo==0.5.0)
#   Using cached cma-2.7.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3->pymoo==0.5.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo==0.5.0) (1.17.0)
# Using cached cma-2.7.0-py2.py3-none-any.whl (239 kB)
# Installing collected packages: cma, pymoo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymoo]32m1/2 [pymoo]
# Successfully installed cma-2.7.0 pymoo-0.5.0

# %%
# DO NOT RUN
# !pip install qiskit==1.4.2
# !pip install qiskit-finance==0.4.1
# !pip install qiskit-aer==0.13.3
# !pip install qiskit-algorithms==0.3.0
# !pip install qiskit-optimization==0.6.1

# !pip install qiskit-aer
# !pip install qiskit
# !pip install qiskit-algorithms
# !pip install qiskit-optimization
# !pip install qiskit-finance
# Out:
# Collecting qiskit==1.4.2
#   Using cached qiskit-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (2.3.3)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (1.16.2)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit==1.4.2) (4.14.1)
# Collecting symengine<0.14,>=0.11 (from qiskit==1.4.2)
#   Using cached symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit==1.4.2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit==1.4.2) (1.3.0)
# Using cached qiskit-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
# Using cached symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
# Installing collected packages: symengine, qiskit
#   Attempting uninstall: symengine
#     Found existing installation: symengine 0.14.1
#     Uninstalling symengine-0.14.1:
#       Successfully uninstalled symengine-0.14.1
#   Attempting uninstall: qiskit━━━━━━━━━━━━━━━━━━ 0/2 [symengine]
#     Found existing installation: qiskit 2.2.2 0/2 [symengine]
#     Uninstalling qiskit-2.2.2:0m╺━━━━━━━━━━━━━━━━━━━ 1/2 [qiskit]
#       Successfully uninstalled qiskit-2.2.2━━━━━━━━━━━━━━━━━━━ 1/2 [qiskit]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [qiskit]2m1/2 [qiskit]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-qiskit 0.72.0 requires qiskit>=2.2.0, but you have qiskit 1.4.2 which is incompatible.
# Successfully installed qiskit-1.4.2 symengine-0.13.0
# Collecting qiskit-finance==0.4.1
#   Using cached qiskit_finance-0.4.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: qiskit>=0.45 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (1.4.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (0.4.0)
# Requirement already satisfied: qiskit-optimization>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (0.7.0)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (2.3.3)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (7.0.0)
# Collecting fastdtw (from qiskit-finance==0.4.1)
#   Using cached fastdtw-0.3.4-py3-none-any.whl
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (80.9.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (2.3.3)
# Collecting nasdaq-data-link (from qiskit-finance==0.4.1)
#   Using cached Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting yfinance>=0.1.70 (from qiskit-finance==0.4.1)
#   Using cached yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (2025.8.3)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance==0.4.1) (2.5.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance==0.4.1) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.45->qiskit-finance==0.4.1) (1.17.0)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization>=0.6.0->qiskit-finance==0.4.1) (2.30.251)
# Requirement already satisfied: networkx>=2.6.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization>=0.6.0->qiskit-finance==0.4.1) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.45->qiskit-finance==0.4.1) (1.3.0)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (2.32.4)
# Collecting multitasking>=0.0.7 (from yfinance>=0.1.70->qiskit-finance==0.4.1)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (2.4.6)
# Collecting peewee>=3.16.2 (from yfinance>=0.1.70->qiskit-finance==0.4.1)
#   Using cached peewee-3.18.2-cp312-cp312-linux_x86_64.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (4.13.4)
# Collecting curl_cffi>=0.7 (from yfinance>=0.1.70->qiskit-finance==0.4.1)
#   Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance==0.4.1) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->qiskit-finance==0.4.1) (2.7)
# Requirement already satisfied: cffi>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance==0.4.1) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance==0.4.1) (2.22)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas->qiskit-finance==0.4.1) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance==0.4.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance==0.4.1) (3.10)
# Collecting inflection>=0.3.1 (from nasdaq-data-link->qiskit-finance==0.4.1)
#   Using cached inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting more-itertools (from nasdaq-data-link->qiskit-finance==0.4.1)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Using cached qiskit_finance-0.4.1-py3-none-any.whl (51 kB)
# Using cached yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl (28 kB)
# Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Installing collected packages: peewee, multitasking, more-itertools, inflection, fastdtw, curl_cffi, yfinance, nasdaq-data-link, qiskit-finance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [qiskit-finance]m [nasdaq-data-link]
# Successfully installed curl_cffi-0.13.0 fastdtw-0.3.4 inflection-0.5.1 more-itertools-10.8.0 multitasking-0.0.12 nasdaq-data-link-1.0.4 peewee-3.18.2 qiskit-finance-0.4.1 yfinance-0.2.66
# Collecting qiskit-aer==0.13.3
#   Using cached qiskit_aer-0.13.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: qiskit>=0.45.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer==0.13.3) (1.4.2)
# Requirement already satisfied: numpy>=1.16.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer==0.13.3) (2.3.3)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer==0.13.3) (1.16.2)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer==0.13.3) (7.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer==0.13.3) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.0->qiskit-aer==0.13.3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.45.0->qiskit-aer==0.13.3) (1.3.0)
# Using cached qiskit_aer-0.13.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Installing collected packages: qiskit-aer
#   Attempting uninstall: qiskit-aer
#     Found existing installation: qiskit-aer 0.17.2
#     Uninstalling qiskit-aer-0.17.2:
#       Successfully uninstalled qiskit-aer-0.17.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-qiskit 0.72.0 requires qiskit>=2.2.0, but you have qiskit 1.4.2 which is incompatible.
# pytket-qiskit 0.72.0 requires qiskit-aer>=0.17.1, but you have qiskit-aer 0.13.3 which is incompatible.
# Successfully installed qiskit-aer-0.13.3
# Collecting qiskit-algorithms==0.3.0
#   Using cached qiskit_algorithms-0.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: qiskit>=0.44 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms==0.3.0) (1.4.2)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms==0.3.0) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms==0.3.0) (2.3.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms==0.3.0) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.44->qiskit-algorithms==0.3.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.44->qiskit-algorithms==0.3.0) (1.3.0)
# Using cached qiskit_algorithms-0.3.0-py3-none-any.whl (308 kB)
# Installing collected packages: qiskit-algorithms
#   Attempting uninstall: qiskit-algorithms
#     Found existing installation: qiskit-algorithms 0.4.0
#     Uninstalling qiskit-algorithms-0.4.0:
#       Successfully uninstalled qiskit-algorithms-0.4.0
# Successfully installed qiskit-algorithms-0.3.0
# Collecting qiskit-optimization==0.6.1
#   Using cached qiskit_optimization-0.6.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: qiskit>=0.44 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (1.4.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (0.3.0)
# Requirement already satisfied: scipy>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (2.3.3)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (2.30.251)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (80.9.0)
# Requirement already satisfied: networkx>=2.6.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization==0.6.1) (3.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization==0.6.1) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization==0.6.1) (0.13.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.44->qiskit-optimization==0.6.1) (1.3.0)
# Using cached qiskit_optimization-0.6.1-py3-none-any.whl (167 kB)
# Installing collected packages: qiskit-optimization
#   Attempting uninstall: qiskit-optimization
#     Found existing installation: qiskit-optimization 0.7.0
#     Uninstalling qiskit-optimization-0.7.0:
#       Successfully uninstalled qiskit-optimization-0.7.0
# Successfully installed qiskit-optimization-0.6.1
# Requirement already satisfied: qiskit-aer in /opt/conda/lib/python3.12/site-packages (0.13.3)
# Requirement already satisfied: qiskit>=0.45.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer) (1.4.2)
# Requirement already satisfied: numpy>=1.16.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer) (2.3.3)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer) (1.16.2)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.12/site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.45.0->qiskit-aer) (1.3.0)
# Requirement already satisfied: qiskit in /opt/conda/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit) (2.3.3)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.12/site-packages (from qiskit) (1.16.2)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: qiskit-algorithms in /opt/conda/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: qiskit>=0.44 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms) (1.4.2)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-algorithms) (2.3.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-algorithms) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.44->qiskit-algorithms) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.44->qiskit-algorithms) (1.3.0)
# Requirement already satisfied: qiskit-optimization in /opt/conda/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: qiskit>=0.44 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (1.4.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (0.3.0)
# Requirement already satisfied: scipy>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (2.3.3)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (2.30.251)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (80.9.0)
# Requirement already satisfied: networkx>=2.6.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization) (3.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.44->qiskit-optimization) (0.13.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.44->qiskit-optimization) (1.3.0)
# Requirement already satisfied: qiskit-finance in /opt/conda/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: qiskit>=0.45 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (1.4.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (0.3.0)
# Requirement already satisfied: qiskit-optimization>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (0.6.1)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (1.16.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (2.3.3)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (7.0.0)
# Requirement already satisfied: fastdtw in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (80.9.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (2.3.3)
# Requirement already satisfied: nasdaq-data-link in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (1.0.4)
# Requirement already satisfied: yfinance>=0.1.70 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (0.2.66)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (2025.8.3)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from qiskit-finance) (2.5.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (4.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/conda/lib/python3.12/site-packages (from qiskit>=0.45->qiskit-finance) (0.13.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit>=0.45->qiskit-finance) (1.17.0)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization>=0.6.0->qiskit-finance) (2.30.251)
# Requirement already satisfied: networkx>=2.6.3 in /opt/conda/lib/python3.12/site-packages (from qiskit-optimization>=0.6.0->qiskit-finance) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=0.45->qiskit-finance) (1.3.0)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in /opt/conda/lib/python3.12/site-packages (from yfinance>=0.1.70->qiskit-finance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->qiskit-finance) (2.7)
# Requirement already satisfied: cffi>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance) (2.22)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas->qiskit-finance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.10)
# Requirement already satisfied: inflection>=0.3.1 in /opt/conda/lib/python3.12/site-packages (from nasdaq-data-link->qiskit-finance) (0.5.1)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.12/site-packages (from nasdaq-data-link->qiskit-finance) (10.8.0)
